# %%
import re
import pandas as pd

# %%
f = open('Whatsapp_chat_with_air_india.txt',"r",encoding="utf-8")

# %%
data= f.read()

# %%
pattern = r'\[\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}:\d{2}\]\s'

# %%
messages = re.split(pattern,data)[1:]

# %%
 dates = re.findall(pattern, data)

# %%
# Create DataFrame
df = pd.DataFrame({'user_message': messages, 'message_date': dates})

# Strip square brackets from 'message_date' column and convert to datetime
try:
    df['message_date'] = pd.to_datetime(df['message_date'].str.strip(), format='[%d/%m/%Y, %H:%M:%S]')
    df.rename(columns={'message_date': 'dates'}, inplace=True)
except ValueError as e:
    print("ValueError:", e)

# %%
# Convert datetime objects to strings
df['dates'] = df['dates'].astype(str)

# Remove brackets and comma from 'dates' column
df['dates'] = df['dates'].str.replace(r'[\[\],]', '', regex=True)

# Convert the strings back to datetime objects
df['dates'] = pd.to_datetime(df['dates'])

df.head()
# Out:
#                                         user_message               dates
# 0  Air India Fam: ‎Messages and calls are end-to-... 2023-10-19 14:42:26
# 1             Suvidhi: ‎Suvidhi created this group\n 2023-10-19 14:42:26
# 2                Air India Fam: ‎Suvidhi added you\n 2023-10-19 18:56:02
# 3                ~ Satnam: ‎~ Poojz added ~ Satnam\n 2023-10-19 18:58:58
# 4           ~ Chandra Deep: Happy & safe journey 🙏\n 2023-10-19 18:58:58

# %%
users = []
messages =[]
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s', message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group notification')
        messages.append(entry[0])
        
df['user']= users
df['message'] = messages
df.drop(columns =['user_message'], inplace= True)

df.head()
# Out:
#                 dates            user  \
# 0 2023-10-19 14:42:26   Air India Fam
# 1 2023-10-19 14:42:26         Suvidhi
# 2 2023-10-19 18:56:02   Air India Fam
# 3 2023-10-19 18:58:58        ~ Satnam
# 4 2023-10-19 18:58:58  ~ Chandra Deep
#
#                                              message
# 0  ‎Messages and calls are end-to-end encrypted. ...
# 1                      ‎Suvidhi created this group\n
# 2                               ‎Suvidhi added you\n
# 3                          ‎~ Poojz added ~ Satnam\n
# 4                           Happy & safe journey 🙏\n

# %%
# Convert the 'date' column to datetime
df['dates'] = pd.to_datetime(df['dates'])

# Extract the date in the desired format (yyyy-mm-dd)
df['dates'] = df['dates'].dt.strftime('%Y-%m-%d %H:%M:%S')

df.head()
# Out:
#                  dates            user  \
# 0  2023-10-19 14:42:26   Air India Fam
# 1  2023-10-19 14:42:26         Suvidhi
# 2  2023-10-19 18:56:02   Air India Fam
# 3  2023-10-19 18:58:58        ~ Satnam
# 4  2023-10-19 18:58:58  ~ Chandra Deep
#
#                                              message
# 0  ‎Messages and calls are end-to-end encrypted. ...
# 1                      ‎Suvidhi created this group\n
# 2                               ‎Suvidhi added you\n
# 3                          ‎~ Poojz added ~ Satnam\n
# 4                           Happy & safe journey 🙏\n

# %%
# Convert the 'dates' column to datetime objects
df['dates'] = pd.to_datetime(df['dates'], errors='coerce')

# Drop rows with NaT (Not a Time) values if any
df = df.dropna(subset=['dates'])

# Extract year from the datetime objects
df['year'] = df['dates'].dt.year

df
# Out:
#                    dates                  user  \
# 0    2023-10-19 14:42:26         Air India Fam
# 1    2023-10-19 14:42:26               Suvidhi
# 2    2023-10-19 18:56:02         Air India Fam
# 3    2023-10-19 18:58:58              ~ Satnam
# 4    2023-10-19 18:58:58        ~ Chandra Deep
# ...                  ...                   ...
# 1047 2024-02-19 08:02:16             ~ Jaswant
# 1048 2024-02-19 11:00:10  ~ Enjoy Every Moment
# 1049 2024-02-19 14:14:58        ~ Chandra Deep
# 1050 2024-02-19 14:15:41        ~ Chandra Deep
# 1051 2024-02-20 08:43:37             ~ Jaswant
#
#                                                 message  year
# 0     ‎Messages and calls are end-to-end encrypted. ...  2023
# 1                         ‎Suvidhi created this group\n  2023
# 2                                  ‎Suvidhi added you\n  2023
# 3                             ‎~ Poojz added ~ Satnam\n  2023
# 4                              Happy & safe journey 🙏\n  2023
# ...                                                 ...   ...
# 1047        This sabad sing in herminder Shaib today\n‎  2024
# 1048                                   ‎image omitted\n  2024
# 1049  # little desi jatt # londan style # dhol lover...  2024
# 1050  Punjabi khoon ubal  maar raha h iska 🤪😂 abhi s...  2024
# 1051                                   ‎video omitted\n  2024
#
# [1052 rows x 4 columns]

# %%
print(df['dates'].dtypes)
# Out:
# datetime64[ns]

# %%
df['dates'] = pd.to_datetime(df['dates'], errors='coerce')

# %%
print(df['dates'].dtypes)
# Out:
# datetime64[ns]

# %%
df['year'] = df['dates'].dt.year

# %%
df
# Out:
#                    dates                  user  \
# 0    2023-10-19 14:42:26         Air India Fam
# 1    2023-10-19 14:42:26               Suvidhi
# 2    2023-10-19 18:56:02         Air India Fam
# 3    2023-10-19 18:58:58              ~ Satnam
# 4    2023-10-19 18:58:58        ~ Chandra Deep
# ...                  ...                   ...
# 1047 2024-02-19 08:02:16             ~ Jaswant
# 1048 2024-02-19 11:00:10  ~ Enjoy Every Moment
# 1049 2024-02-19 14:14:58        ~ Chandra Deep
# 1050 2024-02-19 14:15:41        ~ Chandra Deep
# 1051 2024-02-20 08:43:37             ~ Jaswant
#
#                                                 message  year
# 0     ‎Messages and calls are end-to-end encrypted. ...  2023
# 1                         ‎Suvidhi created this group\n  2023
# 2                                  ‎Suvidhi added you\n  2023
# 3                             ‎~ Poojz added ~ Satnam\n  2023
# 4                              Happy & safe journey 🙏\n  2023
# ...                                                 ...   ...
# 1047        This sabad sing in herminder Shaib today\n‎  2024
# 1048                                   ‎image omitted\n  2024
# 1049  # little desi jatt # londan style # dhol lover...  2024
# 1050  Punjabi khoon ubal  maar raha h iska 🤪😂 abhi s...  2024
# 1051                                   ‎video omitted\n  2024
#
# [1052 rows x 4 columns]

# %%
df['month'] = df['dates'].dt.month_name()

# %%
df['day'] = df['dates'].dt.day

# %%
df['hour'] = df['dates'].dt.hour

# %%
df['minute']= df['dates'].dt.minute

# %%
df
# Out:
#                    dates                  user  \
# 0    2023-10-19 14:42:26         Air India Fam
# 1    2023-10-19 14:42:26               Suvidhi
# 2    2023-10-19 18:56:02         Air India Fam
# 3    2023-10-19 18:58:58              ~ Satnam
# 4    2023-10-19 18:58:58        ~ Chandra Deep
# ...                  ...                   ...
# 1047 2024-02-19 08:02:16             ~ Jaswant
# 1048 2024-02-19 11:00:10  ~ Enjoy Every Moment
# 1049 2024-02-19 14:14:58        ~ Chandra Deep
# 1050 2024-02-19 14:15:41        ~ Chandra Deep
# 1051 2024-02-20 08:43:37             ~ Jaswant
#
#                                                 message  year     month  day  \
# 0     ‎Messages and calls are end-to-end encrypted. ...  2023   October   19
# 1                         ‎Suvidhi created this group\n  2023   October   19
# 2                                  ‎Suvidhi added you\n  2023   October   19
# 3                             ‎~ Poojz added ~ Satnam\n  2023   October   19
# 4                              Happy & safe journey 🙏\n  2023   October   19
# ...                                                 ...   ...       ...  ...
# 1047        This sabad sing in herminder Shaib today\n‎  2024  February   19
# 1048                                   ‎image omitted\n  2024  February   19
# 1049  # little desi jatt # londan style # dhol lover...  2024  February   19
# 1050  Punjabi khoon ubal  maar raha h iska 🤪😂 abhi s...  2024  February   19
# 1051                                   ‎video omitted\n  2024  February   20
#
#       hour  minute
# 0       14      42
# 1       14      42
# 2       18      56
# 3       18      58
# 4       18      58
# ...    ...     ...
# 1047     8       2
# 1048    11       0
# 1049    14      14
# 1050    14      15
# 1051     8      43
#
# [1052 rows x 8 columns]

# %%
words = []
for message in df['message']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 6707

# %%
pip install urlextract
# Out:
# Requirement already satisfied: urlextract in c:\users\sagri\anaconda3\lib\site-packages (1.9.0)
# Requirement already satisfied: uritools in c:\users\sagri\anaconda3\lib\site-packages (from urlextract) (4.0.2)
# Requirement already satisfied: platformdirs in c:\users\sagri\anaconda3\lib\site-packages (from urlextract) (4.2.0)
# Requirement already satisfied: filelock in c:\users\sagri\anaconda3\lib\site-packages (from urlextract) (3.6.0)
# Requirement already satisfied: idna in c:\users\sagri\anaconda3\lib\site-packages (from urlextract) (3.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)

# %%
from urlextract import URLExtract
extractor = URLExtract()
urls = extractor.find_urls("Let's www.gmail.com have URL stackoverflow.com as an example google.com, http://facebook.com")

# %%
urls
# Out:
# ['www.gmail.com', 'stackoverflow.com', 'google.com', 'http://facebook.com']

# %%
links =[]

for message in df['message']:
    links.extend(extractor.find_urls(message))

# %%
links
# Out:
# ['https://www.airindia.com/in/en/contact-us/customer-support-portal/flight-distruption.html#subcategory-items',
#  '1message.co.in/pb/?n=Nirmal-bahara',
#  'https://vm.tiktok.com/ZGe1p6ooy/',
#  'https://www.airindia.com/in/en/contact-us/customer-support-portal/flight-distruption.html#subcategory-items',
#  'https://www.airindia.com/in/en/contact-us/customer-support-portal/flight-distruption.html#subcategory-items',
#  'https://vm.tiktok.com/ZGedJvbkP/',
#  'https://vm.tiktok.com/ZGeRejhpU/',
#  'https://www.instagram.com/reel/C0QUeMzSge-/?igshid=MTc4MmM1YmI2Ng==',
#  'https://youtu.be/OXOZ-vq_ulM?si=QJFdZOL7yVgqLj8e',
#  'lodged.No',
#  '1message.co.in/pb/?n=Nirmal-bahara',
#  'https://youtu.be/SGVXUWsm6Ds?si=0p2LRyOl8hhVYHjc',
#  'https://vm.tiktok.com/ZGeYm5UL2/',
#  'https://vm.tiktok.com/ZGeY9MP2C/',
#  'https://vm.tiktok.com/ZGeMYkbeE/',
#  'https://vm.tiktok.com/ZGeM9XGRm/',
#  'https://www.instagram.com/reel/C2Zx-tYo_tn/?igsh=OTU1ODAwZWUxYg==',
#  'https://www.instagram.com/reel/C3h6tiOoolV/?igsh=NWQ5OTZhYTk5YQ==']

# %%
len(links)
# Out:
# 18

# %%
df
# Out:
#                    dates                  user  \
# 0    2023-10-19 14:42:26         Air India Fam
# 1    2023-10-19 14:42:26               Suvidhi
# 2    2023-10-19 18:56:02         Air India Fam
# 3    2023-10-19 18:58:58              ~ Satnam
# 4    2023-10-19 18:58:58        ~ Chandra Deep
# ...                  ...                   ...
# 1047 2024-02-19 08:02:16             ~ Jaswant
# 1048 2024-02-19 11:00:10  ~ Enjoy Every Moment
# 1049 2024-02-19 14:14:58        ~ Chandra Deep
# 1050 2024-02-19 14:15:41        ~ Chandra Deep
# 1051 2024-02-20 08:43:37             ~ Jaswant
#
#                                                 message  year     month  day  \
# 0     ‎Messages and calls are end-to-end encrypted. ...  2023   October   19
# 1                         ‎Suvidhi created this group\n  2023   October   19
# 2                                  ‎Suvidhi added you\n  2023   October   19
# 3                             ‎~ Poojz added ~ Satnam\n  2023   October   19
# 4                              Happy & safe journey 🙏\n  2023   October   19
# ...                                                 ...   ...       ...  ...
# 1047        This sabad sing in herminder Shaib today\n‎  2024  February   19
# 1048                                   ‎image omitted\n  2024  February   19
# 1049  # little desi jatt # londan style # dhol lover...  2024  February   19
# 1050  Punjabi khoon ubal  maar raha h iska 🤪😂 abhi s...  2024  February   19
# 1051                                   ‎video omitted\n  2024  February   20
#
#       hour  minute
# 0       14      42
# 1       14      42
# 2       18      56
# 3       18      58
# 4       18      58
# ...    ...     ...
# 1047     8       2
# 1048    11       0
# 1049    14      14
# 1050    14      15
# 1051     8      43
#
# [1052 rows x 8 columns]

# %%
x=df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
name = x.index
count = x.values

# %%
plt.bar(name,count)
plt.xticks(rotation='vertical')
plt.show()

# %%
round((df['user'].value_counts()/df.shape[0])*100,2).reset_index().rename(columns={'index':'name','user':'percent'})
# Out:
#                      name  percent
# 0          ~ Chandra Deep    13.78
# 1               ~ Jaswant    13.50
# 2         ~ Nirmal Bahara    10.36
# 3                ~ Satnam     6.75
# 4          ~ Lakhan Singh     5.80
# 5            ~ iiiiiiiiii     5.80
# 6   Anita Aunty Heathrow      5.04
# 7                  ~ Ravi     4.94
# 8        ~ kunal patel601     4.09
# 9              ~ Manmohan     3.99
# 10                ~ Preet     3.33
# 11                ~ Poojz     2.85
# 12              ~ Pritesh     2.47
# 13                Suvidhi     1.90
# 14   ~ Enjoy Every Moment     1.90
# 15                ~ 😁Mita     1.71
# 16        ~ Kultar Bahara     1.43
# 17                ~ Pooja     1.43
# 18                ~ Sonal     1.24
# 19           ~ Piyali Roy     1.24
# 20              ~ Jasleen     1.24
# 21               ~ Asveen     1.14
# 22                ~ Jin K     0.86
# 23    ~ Nupur Shrivastava     0.67
# 24   ~ Kartikeya Mehrotra     0.67
# 25                ~ Venky     0.48
# 26              ~ Supreet     0.48
# 27              ~ Jagdeep     0.29
# 28          Air India Fam     0.29
# 29          ~ Udhey Pujji     0.19
# 30      ‪+91 89293 88990‬     0.10
# 31      ‪+44 7769 385988‬     0.10

# %%
temp=df[df['user'] !='group_notification']
temp[temp['message'] != 'media omitted\n']
# Out:
#                    dates                  user  \
# 0    2023-10-19 14:42:26         Air India Fam
# 1    2023-10-19 14:42:26               Suvidhi
# 2    2023-10-19 18:56:02         Air India Fam
# 3    2023-10-19 18:58:58              ~ Satnam
# 4    2023-10-19 18:58:58        ~ Chandra Deep
# ...                  ...                   ...
# 1047 2024-02-19 08:02:16             ~ Jaswant
# 1048 2024-02-19 11:00:10  ~ Enjoy Every Moment
# 1049 2024-02-19 14:14:58        ~ Chandra Deep
# 1050 2024-02-19 14:15:41        ~ Chandra Deep
# 1051 2024-02-20 08:43:37             ~ Jaswant
#
#                                                 message  year     month  day  \
# 0     ‎Messages and calls are end-to-end encrypted. ...  2023   October   19
# 1                         ‎Suvidhi created this group\n  2023   October   19
# 2                                  ‎Suvidhi added you\n  2023   October   19
# 3                             ‎~ Poojz added ~ Satnam\n  2023   October   19
# 4                              Happy & safe journey 🙏\n  2023   October   19
# ...                                                 ...   ...       ...  ...
# 1047        This sabad sing in herminder Shaib today\n‎  2024  February   19
# 1048                                   ‎image omitted\n  2024  February   19
# 1049  # little desi jatt # londan style # dhol lover...  2024  February   19
# 1050  Punjabi khoon ubal  maar raha h iska 🤪😂 abhi s...  2024  February   19
# 1051                                   ‎video omitted\n  2024  February   20
#
#       hour  minute
# 0       14      42
# 1       14      42
# 2       18      56
# 3       18      58
# 4       18      58
# ...    ...     ...
# 1047     8       2
# 1048    11       0
# 1049    14      14
# 1050    14      15
# 1051     8      43
#
# [1052 rows x 8 columns]

# %%
f = open("C:/Users/sagri/Downloads/stop_hinglish.txt",'r')
stop_words = f.read()
print(stop_words)
# Out:
# a
# aadi
# aaj
# aap
# aapne
# aata
# aati
# aaya
# aaye
# ab
# abbe
# abbey
# abe
# abhi
# able
# about
# above
# accha
# according
# accordingly
# acha
# achcha
# across
# actually
# after
# afterwards
# again
# against
# agar
# ain
# aint
# ain't
# aisa
# aise
# aisi
# alag
# all
# allow
# allows
# almost
# alone
# along
# already
# also
# although
# always
# am
# among
# amongst
# an
# and
# andar
# another
# any
# anybody
# anyhow
# anyone
# anything
# anyway
# anyways
# anywhere
# ap
# apan
# apart
# apna
# apnaa
# apne
# apni
# appear
# are
# aren
# arent
# aren't
# around
# arre
# as
# aside
# ask
# asking
# at
# aur
# avum
# aya
# aye
# baad
# baar
# bad
# bahut
# bana
# banae
# banai
# banao
# banaya
# banaye
# banayi
# banda
# bande
# bandi
# bane
# bani
# bas
# bata
# batao
# bc
# be
# became
# because
# become
# becomes
# becoming
# been
# before
# beforehand
# behind
# being
# below
# beside
# besides
# best
# better
# between
# beyond
# bhai
# bheetar
# bhi
# bhitar
# bht
# bilkul
# bohot
# bol
# bola
# bole
# boli
# bolo
# bolta
# bolte
# bolti
# both
# brief
# bro
# btw
# but
# by
# came
# can
# cannot
# cant
# can't
# cause
# causes
# certain
# certainly
# chahiye
# chaiye
# chal
# chalega
# chhaiye
# clearly
# c'mon
# com
# come
# comes
# could
# couldn
# couldnt
# couldn't
# d
# de
# dede
# dega
# degi
# dekh
# dekha
# dekhe
# dekhi
# dekho
# denge
# dhang
# di
# did
# didn
# didnt
# didn't
# dijiye
# diya
# diyaa
# diye
# diyo
# do
# does
# doesn
# doesnt
# doesn't
# doing
# done
# dono
# dont
# don't
# doosra
# doosre
# down
# downwards
# dude
# dunga
# dungi
# during
# dusra
# dusre
# dusri
# dvaara
# dvara
# dwaara
# dwara
# each
# edu
# eg
# eight
# either
# ek
# else
# elsewhere
# enough
# etc
# even
# ever
# every
# everybody
# everyone
# everything
# everywhere
# ex
# exactly
# example
# except
# far
# few
# fifth
# fir
# first
# five
# followed
# following
# follows
# for
# forth
# four
# from
# further
# furthermore
# gaya
# gaye
# gayi
# get
# gets
# getting
# ghar
# given
# gives
# go
# goes
# going
# gone
# good
# got
# gotten
# greetings
# haan
# had
# hadd
# hadn
# hadnt
# hadn't
# hai
# hain
# hamara
# hamare
# hamari
# hamne
# han
# happens
# har
# hardly
# has
# hasn
# hasnt
# hasn't
# have
# haven
# havent
# haven't
# having
# he
# hello
# help
# hence
# her
# here
# hereafter
# hereby
# herein
# here's
# hereupon
# hers
# herself
# he's
# hi
# him
# himself
# his
# hither
# hm
# hmm
# ho
# hoga
# hoge
# hogi
# hona
# honaa
# hone
# honge
# hongi
# honi
# hopefully
# hota
# hotaa
# hote
# hoti
# how
# howbeit
# however
# hoyenge
# hoyengi
# hu
# hua
# hue
# huh
# hui
# hum
# humein
# humne
# hun
# huye
# huyi
# i
# i'd
# idk
# ie
# if
# i'll
# i'm
# imo
# in
# inasmuch
# inc
# inhe
# inhi
# inho
# inka
# inkaa
# inke
# inki
# inn
# inner
# inse
# insofar
# into
# inward
# is
# ise
# isi
# iska
# iskaa
# iske
# iski
# isme
# isn
# isne
# isnt
# isn't
# iss
# isse
# issi
# isski
# it
# it'd
# it'll
# itna
# itne
# itni
# itno
# its
# it's
# itself
# ityaadi
# ityadi
# i've
# ja
# jaa
# jab
# jabh
# jaha
# jahaan
# jahan
# jaisa
# jaise
# jaisi
# jata
# jayega
# jidhar
# jin
# jinhe
# jinhi
# jinho
# jinhone
# jinka
# jinke
# jinki
# jinn
# jis
# jise
# jiska
# jiske
# jiski
# jisme
# jiss
# jisse
# jitna
# jitne
# jitni
# jo
# just
# jyaada
# jyada
# k
# ka
# kaafi
# kab
# kabhi
# kafi
# kaha
# kahaa
# kahaan
# kahan
# kahi
# kahin
# kahte
# kaisa
# kaise
# kaisi
# kal
# kam
# kar
# kara
# kare
# karega
# karegi
# karen
# karenge
# kari
# karke
# karna
# karne
# karni
# karo
# karta
# karte
# karti
# karu
# karun
# karunga
# karungi
# kaun
# kaunsa
# kayi
# kch
# ke
# keep
# keeps
# keh
# kehte
# kept
# khud
# ki
# kin
# kine
# kinhe
# kinho
# kinka
# kinke
# kinki
# kinko
# kinn
# kino
# kis
# kise
# kisi
# kiska
# kiske
# kiski
# kisko
# kisliye
# kisne
# kitna
# kitne
# kitni
# kitno
# kiya
# kiye
# know
# known
# knows
# ko
# koi
# kon
# konsa
# koyi
# krna
# krne
# kuch
# kuchch
# kuchh
# kul
# kull
# kya
# kyaa
# kyu
# kyuki
# kyun
# kyunki
# lagta
# lagte
# lagti
# last
# lately
# later
# le
# least
# lekar
# lekin
# less
# lest
# let
# let's
# li
# like
# liked
# likely
# little
# liya
# liye
# ll
# lo
# log
# logon
# lol
# look
# looking
# looks
# ltd
# lunga
# m
# maan
# maana
# maane
# maani
# maano
# magar
# mai
# main
# maine
# mainly
# mana
# mane
# mani
# mano
# many
# mat
# may
# maybe
# me
# mean
# meanwhile
# mein
# mera
# mere
# merely
# meri
# might
# mightn
# mightnt
# mightn't
# mil
# mjhe
# more
# moreover
# most
# mostly
# much
# mujhe
# must
# mustn
# mustnt
# mustn't
# my
# myself
# na
# naa
# naah
# nahi
# nahin
# nai
# name
# namely
# nd
# ne
# near
# nearly
# necessary
# neeche
# need
# needn
# neednt
# needn't
# needs
# neither
# never
# nevertheless
# new
# next
# nhi
# nine
# no
# nobody
# non
# none
# noone
# nope
# nor
# normally
# not
# nothing
# novel
# now
# nowhere
# o
# obviously
# of
# off
# often
# oh
# ok
# okay
# old
# on
# once
# one
# ones
# only
# onto
# or
# other
# others
# otherwise
# ought
# our
# ours
# ourselves
# out
# outside
# over
# overall
# own
# par
# pata
# pe
# pehla
# pehle
# pehli
# people
# per
# perhaps
# phla
# phle
# phli
# placed
# please
# plus
# poora
# poori
# provides
# pura
# puri
# q
# que
# quite
# raha
# rahaa
# rahe
# rahi
# rakh
# rakha
# rakhe
# rakhen
# rakhi
# rakho
# rather
# re
# really
# reasonably
# regarding
# regardless
# regards
# rehte
# rha
# rhaa
# rhe
# rhi
# ri
# right
# s
# sa
# saara
# saare
# saath
# sab
# sabhi
# sabse
# sahi
# said
# sakta
# saktaa
# sakte
# sakti
# same
# sang
# sara
# sath
# saw
# say
# saying
# says
# se
# second
# secondly
# see
# seeing
# seem
# seemed
# seeming
# seems
# seen
# self
# selves
# sensible
# sent
# serious
# seriously
# seven
# several
# shall
# shan
# shant
# shan't
# she
# she's
# should
# shouldn
# shouldnt
# shouldn't
# should've
# si
# since
# six
# so
# soch
# some
# somebody
# somehow
# someone
# something
# sometime
# sometimes
# somewhat
# somewhere
# soon
# still
# sub
# such
# sup
# sure
# t
# tab
# tabh
# tak
# take
# taken
# tarah
# teen
# teeno
# teesra
# teesre
# teesri
# tell
# tends
# tera
# tere
# teri
# th
# tha
# than
# thank
# thanks
# thanx
# that
# that'll
# thats
# that's
# the
# theek
# their
# theirs
# them
# themselves
# then
# thence
# there
# thereafter
# thereby
# therefore
# therein
# theres
# there's
# thereupon
# these
# they
# they'd
# they'll
# they're
# they've
# thi
# thik
# thing
# think
# thinking
# third
# this
# tho
# thoda
# thodi
# thorough
# thoroughly
# those
# though
# thought
# three
# through
# throughout
# thru
# thus
# tjhe
# to
# together
# toh
# too
# took
# toward
# towards
# tried
# tries
# true
# truly
# try
# trying
# tu
# tujhe
# tum
# tumhara
# tumhare
# tumhari
# tune
# twice
# two
# um
# umm
# un
# under
# unhe
# unhi
# unho
# unhone
# unka
# unkaa
# unke
# unki
# unko
# unless
# unlikely
# unn
# unse
# until
# unto
# up
# upar
# upon
# us
# use
# used
# useful
# uses
# usi
# using
# uska
# uske
# usne
# uss
# usse
# ussi
# usually
# vaala
# vaale
# vaali
# vahaan
# vahan
# vahi
# vahin
# vaisa
# vaise
# vaisi
# vala
# vale
# vali
# various
# ve
# very
# via
# viz
# vo
# waala
# waale
# waali
# wagaira
# wagairah
# wagerah
# waha
# wahaan
# wahan
# wahi
# wahin
# waisa
# waise
# waisi
# wala
# wale
# wali
# want
# wants
# was
# wasn
# wasnt
# wasn't
# way
# we
# we'd
# well
# we'll
# went
# were
# we're
# weren
# werent
# weren't
# we've
# what
# whatever
# what's
# when
# whence
# whenever
# where
# whereafter
# whereas
# whereby
# wherein
# where's
# whereupon
# wherever
# whether
# which
# while
# who
# whoever
# whole
# whom
# who's
# whose
# why
# will
# willing
# with
# within
# without
# wo
# woh
# wohi
# won
# wont
# won't
# would
# wouldn
# wouldnt
# wouldn't
# y
# ya
# yadi
# yah
# yaha
# yahaan
# yahan
# yahi
# yahin
# ye
# yeah
# yeh
# yehi
# yes
# yet
# you
# you'd
# you'll
# your
# you're
# yours
# yourself
# yourselves
# you've
# yup

# %%
words = []

for message in temp['message']:
    for word in message.lower().split():
        if word not in stop_words:
            words.append(word)

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#                   0    1
# 0           omitted  395
# 1                 ‎  374
# 2            ‎image  236
# 3            ‎video  103
# 4          ‎sticker   45
# 5             india   39
# 6            family   28
# 7             happy   24
# 8           morning   22
# 9              nice   21
# 10           lovely   21
# 11             meet   21
# 12             back   18
# 13            claim   18
# 14                🙏   17
# 15         received   17
# 16            enjoy   16
# 17          message   16
# 18  congratulations   16
# 19            added   15

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in c:\users\sagri\anaconda3\lib\site-packages (2.10.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\sagri\anaconda3\lib\site-packages)

# %%
import emoji

# %%
import emoji
import regex as re

def extract_emojis(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return ''.join(emoji_pattern.findall(text))

# Example usage:
emojis = []
for message in df['message']:
    emojis.extend(extract_emojis(message))

# %%
emojis
# Out:
# ['🙏',
#  '🍻',
#  '😍',
#  '🙏',
#  '👏',
#  '🎉',
#  '👍',
#  '🙏',
#  '👍',
#  '🏻',
#  '👍',
#  '🙏',
#  '🤗',
#  '❤',
#  '️',
#  '😁',
#  '👌',
#  '💕',
#  '🌈',
#  '🤪',
#  '❤',
#  '️',
#  '🙏',
#  '👍',
#  '🏻',
#  '😀',
#  '🙏',
#  '🌈',
#  '👍',
#  '💕',
#  '❤',
#  '️',
#  '🙏',
#  '😃',
#  '💕',
#  '🙏',
#  '👌',
#  '💐',
#  '😊',
#  '🙏',
#  '🏽',
#  '🙏',
#  '🏽',
#  '❤',
#  '️',
#  '👍',
#  '🏾',
#  '🙏',
#  '🏾',
#  '🥺',
#  '🥺',
#  '\U0001faf6',
#  '🏻',
#  '\U0001faf6',
#  '🏻',
#  '\U0001faf6',
#  '🏻',
#  '💕',
#  '💕',
#  '💕',
#  '☺',
#  '️',
#  '😄',
#  '😄',
#  '💕',
#  '🤗',
#  '😘',
#  '👌',
#  '👌',
#  '🧿',
#  '❤',
#  '️',
#  '🙏',
#  '🏻',
#  '🙏',
#  '🏽',
#  '🙏',
#  '🙏',
#  '🙏',
#  '😁',
#  '😁',
#  '❤',
#  '️',
#  '👍',
#  '🥰',
#  '🙏',
#  '🏻',
#  '🙏',
#  '🌈',
#  '😊',
#  '🙏',
#  '👍',
#  '🥳',
#  '💐',
#  '🎉',
#  '👍',
#  '🏾',
#  '🙏',
#  '🏾',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '👍',
#  '🙏',
#  '🙏',
#  '❤',
#  '️',
#  '🙏',
#  '❤',
#  '️',
#  '😍',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🏻',
#  '🙏',
#  '😊',
#  '🙏',
#  '🙏',
#  '👏',
#  '👏',
#  '👌',
#  '👌',
#  '🧿',
#  '🙏',
#  '🇬',
#  '🇧',
#  '👍',
#  '👍',
#  '🏾',
#  '🙏',
#  '🏾',
#  '👍',
#  '🏾',
#  '🙏',
#  '🏾',
#  '👍',
#  '\U0001faf6',
#  '🏻',
#  '🙏',
#  '🙏',
#  '🥰',
#  '🙏',
#  '🙏',
#  '🌹',
#  '🌹',
#  '🙏',
#  '🏾',
#  '🇮',
#  '🇳',
#  '🇮',
#  '🇳',
#  '🙏',
#  '🙏',
#  '🤗',
#  '✈',
#  '️',
#  '🇮',
#  '🇳',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '🎁',
#  '💁',
#  '👇',
#  '👇',
#  '👇',
#  '🪔',
#  '🪔',
#  '🙏',
#  '🏾',
#  '💯',
#  '💥',
#  '🪔',
#  '🪔',
#  '🪔',
#  '🪔',
#  '👏',
#  '👏',
#  '🙌',
#  '👍',
#  '👌',
#  '👍',
#  '👍',
#  '🏻',
#  '👍',
#  '❤',
#  '️',
#  '🙏',
#  '🏽',
#  '👍',
#  '🏾',
#  '🙏',
#  '🏾',
#  '👍',
#  '🙏',
#  '🌈',
#  '💕',
#  '😄',
#  '🧈',
#  '🤤',
#  '😔',
#  '🤪',
#  '🥰',
#  '👌',
#  '👍',
#  '🙏',
#  '🙏',
#  '😁',
#  '👍',
#  '☝',
#  '️',
#  '😊',
#  '🌹',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🏻',
#  '😊',
#  '😗',
#  '😏',
#  '😝',
#  '😇',
#  '😂',
#  '🥺',
#  '💪',
#  '😳',
#  '👌',
#  '🤗',
#  '😇',
#  '😊',
#  '😆',
#  '😂',
#  '🤣',
#  '😍',
#  '🤣',
#  '🤣',
#  '😆',
#  '🥰',
#  '🙏',
#  '🏻',
#  '💰',
#  '🤑',
#  '😊',
#  '🙏',
#  '🙏',
#  '🎁',
#  '💁',
#  '👇',
#  '👇',
#  '👇',
#  '🙏',
#  '🏽',
#  '🙏',
#  '🏽',
#  '🥳',
#  '🎉',
#  '🎉',
#  '🎉',
#  '🎉',
#  '🍾',
#  '🥂',
#  '❤',
#  '️',
#  '💐',
#  '🤗',
#  '🙏',
#  '🙏',
#  '☺',
#  '️',
#  '🙌',
#  '🙏',
#  '🌈',
#  '🌹',
#  '👍',
#  '🌹',
#  '🙏',
#  '🏻',
#  '🙏',
#  '🏻',
#  '👍',
#  '👌',
#  '❤',
#  '️',
#  '🌹',
#  '😊',
#  '❤',
#  '️',
#  '🙏',
#  '🏽',
#  '❤',
#  '️',
#  '💕',
#  '❤',
#  '️',
#  '🙏',
#  '❤',
#  '️',
#  '🙏',
#  '🏻',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🏽',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '🙏',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '🙏',
#  '🙏',
#  '🥰',
#  '🌅',
#  '🙏',
#  '🙏',
#  '👌',
#  '👌',
#  '👍',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🏽',
#  '🙏',
#  '🙏',
#  '😜',
#  '😜',
#  '🌈',
#  '💕',
#  '🌹',
#  '🌈',
#  '😉',
#  '👍',
#  '❤',
#  '️',
#  '❤',
#  '️',
#  '🌹',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🙏',
#  '🏽',
#  '🙏',
#  '🏽',
#  '💐',
#  '❤',
#  '️',
#  '🌈',
#  '👍',
#  '👍',
#  '🤪',
#  '😂']

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#     0   1
# 0   🙏  89
# 1   ️  30
# 2   👍  28
# 3   ❤  26
# 4   🏻  15
# .. ..  ..
# 57  🤑   1
# 58  🍾   1
# 59  🥂   1
# 60  🌅   1
# 61  😉   1
#
# [62 rows x 2 columns]

# %%
df['month_num'] = df['dates'].dt.month

# %%
timeline= df.groupby(['year','month_num','month']).count()['message'].reset_index()

# %%
timeline
# Out:
#    year  month_num     month  message
# 0  2023         10   October      366
# 1  2023         11  November      259
# 2  2023         12  December      154
# 3  2024          1   January      159
# 4  2024          2  February      114

# %%
time=[]

for i in range(timeline.shape[0]):
    time.append(timeline['month'][i] + "-" + str(timeline["year"][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#    year  month_num     month  message           time
# 0  2023         10   October      366   October-2023
# 1  2023         11  November      259  November-2023
# 2  2023         12  December      154  December-2023
# 3  2024          1   January      159   January-2024
# 4  2024          2  February      114  February-2024

# %%
plt.plot(timeline['time'],timeline['message'])
plt.xticks(rotation="vertical")
plt.show()

# %%
df['only_date']=df['dates'].dt.date

# %%
daily_timeline= df.groupby("only_date").count()['message'].reset_index()

# %%
plt.figure(figsize =(18,10))
plt.plot(daily_timeline['only_date'],daily_timeline['message'])

# %%
df.head()
# Out:
#                 dates            user  \
# 0 2023-10-19 14:42:26   Air India Fam
# 1 2023-10-19 14:42:26         Suvidhi
# 2 2023-10-19 18:56:02   Air India Fam
# 3 2023-10-19 18:58:58        ~ Satnam
# 4 2023-10-19 18:58:58  ~ Chandra Deep
#
#                                              message  year    month  day  \
# 0  ‎Messages and calls are end-to-end encrypted. ...  2023  October   19
# 1                      ‎Suvidhi created this group\n  2023  October   19
# 2                               ‎Suvidhi added you\n  2023  October   19
# 3                          ‎~ Poojz added ~ Satnam\n  2023  October   19
# 4                           Happy & safe journey 🙏\n  2023  October   19
#
#    hour  minute  month_num   only_date
# 0    14      42         10  2023-10-19
# 1    14      42         10  2023-10-19
# 2    18      56         10  2023-10-19
# 3    18      58         10  2023-10-19
# 4    18      58         10  2023-10-19

# %%
df['day_name']=df['dates'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# Friday       230
# Sunday       197
# Saturday     175
# Monday       139
# Wednesday    119
# Thursday     110
# Tuesday       82
# Name: day_name, dtype: int64

# %%
df['month'].value_counts()
# Out:
# October     366
# November    259
# January     159
# December    154
# February    114
# Name: month, dtype: int64

# %%
period = []
for hour in df[['day_name','hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour == 0:
        period.append(str('00') + "-" +str(hour+1))
    else:
        period.append(str(hour) + "-" + str(hour+1))

# %%
df['period'] = period

# %%
df.sample(5)
# Out:
#                    dates            user                          message  \
# 219  2023-10-23 05:13:30  ~ Chandra Deep               ‎sticker omitted\n
# 302  2023-10-26 05:26:33  ~ Chandra Deep               ‎sticker omitted\n
# 1036 2024-02-17 13:10:58  ~ Chandra Deep        Congratulations veer ji\n
# 788  2024-01-01 02:58:54         ~ Preet  Happy new year to all of you\n‎
# 188  2023-10-22 06:46:21  ~ Chandra Deep                ‎video omitted\n‎
#
#       year     month  day  hour  minute  month_num   only_date  day_name  \
# 219   2023   October   23     5      13         10  2023-10-23    Monday
# 302   2023   October   26     5      26         10  2023-10-26  Thursday
# 1036  2024  February   17    13      10          2  2024-02-17  Saturday
# 788   2024   January    1     2      58          1  2024-01-01    Monday
# 188   2023   October   22     6      46         10  2023-10-22    Sunday
#
#      period
# 219     5-6
# 302     5-6
# 1036  13-14
# 788     2-3
# 188     6-7

# %%
import seaborn as sns
plt.figure(figsize=(20,6))
sns.heatmap(df.pivot_table(index="day_name", columns="period", values="message",aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
